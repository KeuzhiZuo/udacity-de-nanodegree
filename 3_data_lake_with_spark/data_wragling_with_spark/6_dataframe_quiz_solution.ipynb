# %% [markdown]
# # Answer Key to the Data Wrangling with DataFrames Coding Quiz
#
# Helpful resources:
# https://spark.apache.org/docs/2.4.0/api/python/pyspark.sql.html

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import isnan, count, when, col, desc, udf, col, sort_array, asc, avg
from pyspark.sql.functions import sum as Fsum
from pyspark.sql.window import Window
from pyspark.sql.types import IntegerType

# %%
# 1) import any other libraries you might need
# 2) instantiate a Spark session 
# 3) read in the data set located at the path "data/sparkify_log_small.json"
# 4) write code to answer the quiz questions 

spark = SparkSession \
    .builder \
    .appName("Data Frames practice") \
    .getOrCreate()

df = spark.read.json("data/sparkify_log_small.json")

# %% [markdown]
# # Question 1
#
# Which page did user id "" (empty string) NOT visit?

# %%
df.printSchema()
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: long (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)

# %%
# filter for users with blank user id
blank_pages = df.filter(df.userId == '') \
    .select(col('page') \
    .alias('blank_pages')) \
    .dropDuplicates()

# get a list of possible pages that could be visited
all_pages = df.select('page').dropDuplicates()

# find values in all_pages that are not in blank_pages
# these are the pages that the blank user did not go to
for row in set(all_pages.collect()) - set(blank_pages.collect()):
    print(row.page)
# Out:
# Logout
# Upgrade
# Settings
# NextSong
# Downgrade
# Save Settings
# Submit Upgrade
# Error
# Submit Downgrade

# %% [markdown]
# # Question 2 - Reflect
#
# What type of user does the empty string user id most likely refer to?

# %% [markdown]
# Perhaps it represents users who have not signed up yet or who are signed out and are about to log in.

# %% [markdown]
# # Question 3
#
# How many female users do we have in the data set?

# %%
df.filter(df.gender == 'F') \
    .select('userId', 'gender') \
    .dropDuplicates() \
    .count()
# Out:
# 462

# %% [markdown]
# # Question 4
#
# How many songs were played from the most played artist?

# %%
df.groupBy('Artist').agg({'song':'count'})\
    .withColumnRenamed('count(song)', 'songcnt')\
    .sort(desc('songcnt')).show(1)
# Out:
# +--------+-------+
# |  Artist|songcnt|
# +--------+-------+
# |Coldplay|     83|
# +--------+-------+
# only showing top 1 row

# %%
df.filter(df.page == 'NextSong') \
    .select('Artist') \
    .groupBy('Artist') \
    .agg({'Artist':'count'}) \
    .withColumnRenamed('count(Artist)', 'Artistcount') \
    .sort(desc('Artistcount')) \
    .show(1)
# Out:
# +--------+-----------+
# |  Artist|Artistcount|
# +--------+-----------+
# |Coldplay|         83|
# +--------+-----------+
# only showing top 1 row

# %% [markdown]
# # Question 5 (challenge)
#
# How many songs do users listen to on average between visiting our home page? Please round your answer to the closest integer.

# %%
df.select('page').dropDuplicates().collect()
# Out:
# [Row(page='Submit Downgrade'),
#  Row(page='Home'),
#  Row(page='Downgrade'),
#  Row(page='Logout'),
#  Row(page='Save Settings'),
#  Row(page='About'),
#  Row(page='Settings'),
#  Row(page='Login'),
#  Row(page='NextSong'),
#  Row(page='Help'),
#  Row(page='Upgrade'),
#  Row(page='Error'),
#  Row(page='Submit Upgrade')]

# %%
df.select('ts').dropDuplicates().collect()
# Out:
# [Row(ts=1513721088284),
#  Row(ts=1513722979284),
#  Row(ts=1513724468284),
#  Row(ts=1513731400284),
#  Row(ts=1513731936284),
#  Row(ts=1513732013284),
#  Row(ts=1513737890284),
#  Row(ts=1513741516284),
#  Row(ts=1513741886284),
#  Row(ts=1513745684284),
#  Row(ts=1513746941284),
#  Row(ts=1513750442284),
#  Row(ts=1513757271284),
#  Row(ts=1513764103284),
#  Row(ts=1513764509284),
#  Row(ts=1513764784284),
#  Row(ts=1513765481284),
#  Row(ts=1513765531284),
#  Row(ts=1513768268284),
#  Row(ts=1513769485284),
#  Row(ts=1513770651284),
#  Row(ts=1513773671284),
#  Row(ts=1513773765284),
#  Row(ts=1513774487284),
#  Row(ts=1513774809284),
#  Row(ts=1513777935284),
#  Row(ts=1513780747284),
#  Row(ts=1513780897284),
#  Row(ts=1513781090284),
#  Row(ts=1513781248284),
#  Row(ts=1513781283284),
#  Row(ts=1513783316284),
#  Row(ts=1513783658284),
#  Row(ts=1513784141284),
#  Row(ts=1513786569284),
#  Row(ts=1513787089284),
#  Row(ts=1513787704284),
#  Row(ts=1513788238284),
#  Row(ts=1513789458284),
#  Row(ts=1513790802284),
#  Row(ts=1513796399284),
#  Row(ts=1513798814284),
#  Row(ts=1513799227284),
#  Row(ts=1513799281284),
#  Row(ts=1513799521284),
#  Row(ts=1513799928284),
#  Row(ts=1513803252284),
#  Row(ts=1513805414284),
#  Row(ts=1513806161284),
#  Row(ts=1513807057284),
#  Row(ts=1513812985284),
#  Row(ts=1513817806284),
#  Row(ts=1513820004284),
#  Row(ts=1513821618284),
#  Row(ts=1513826964284),
#  Row(ts=1513832076284),
#  Row(ts=1513835594284),
#  Row(ts=1513840790284),
#  Row(ts=1513846088284),
#  Row(ts=1513846156284),
#  Row(ts=1513847395284),
#  Row(ts=1513723053284),
#  Row(ts=1513725100284),
#  Row(ts=1513728278284),
#  Row(ts=1513729763284),
#  Row(ts=1513732719284),
#  Row(ts=1513733358284),
#  Row(ts=1513738846284),
#  Row(ts=1513741877284),
#  Row(ts=1513743844284),
#  Row(ts=1513746819284),
#  Row(ts=1513749208284),
#  Row(ts=1513762872284),
#  Row(ts=1513765308284),
#  Row(ts=1513766610284),
#  Row(ts=1513766873284),
#  Row(ts=1513768309284),
#  Row(ts=1513771544284),
#  Row(ts=1513771963284),
#  Row(ts=1513772410284),
#  Row(ts=1513779536284),
#  Row(ts=1513780776284),
#  Row(ts=1513780830284),
#  Row(ts=1513780892284),
#  Row(ts=1513781202284),
#  Row(ts=1513781260284),
#  Row(ts=1513781416284),
#  Row(ts=1513783260284),
#  Row(ts=1513785745284),
#  Row(ts=1513786770284),
#  Row(ts=1513786895284),
#  Row(ts=1513787942284),
#  Row(ts=1513788288284),
#  Row(ts=1513788328284),
#  Row(ts=1513789379284),
#  Row(ts=1513793821284),
#  Row(ts=1513795752284),
#  Row(ts=1513800510284),
#  Row(ts=1513801880284),
#  Row(ts=1513802469284),
#  Row(ts=1513804008284),
#  Row(ts=1513806022284),
#  Row(ts=1513807795284),
#  Row(ts=1513810966284),
#  Row(ts=1513813285284),
#  Row(ts=1513815495284),
#  Row(ts=1513817344284),
#  Row(ts=1513818211284),
#  Row(ts=1513822223284),
#  Row(ts=1513827823284),
#  Row(ts=1513830488284),
#  Row(ts=1513830545284),
#  Row(ts=1513842367284),
#  Row(ts=1513847787284),
#  Row(ts=1513721097284),
#  Row(ts=1513721591284),
#  Row(ts=1513725290284),
#  Row(ts=1513727034284),
#  Row(ts=1513728737284),
#  Row(ts=1513730735284),
#  Row(ts=1513734177284),
#  Row(ts=1513743286284),
#  Row(ts=1513743689284),
#  Row(ts=1513745264284),
#  Row(ts=1513746353284),
#  Row(ts=1513747192284),
#  Row(ts=1513747939284),
#  Row(ts=1513749404284),
#  Row(ts=1513751897284),
#  Row(ts=1513756381284),
#  Row(ts=1513763475284),
#  Row(ts=1513769574284),
#  Row(ts=1513772788284),
#  Row(ts=1513772849284),
#  Row(ts=1513774346284),
#  Row(ts=1513775349284),
#  Row(ts=1513776933284),
#  Row(ts=1513777114284),
#  Row(ts=1513780466284),
#  Row(ts=1513784730284),
#  Row(ts=1513785619284),
#  Row(ts=1513788860284),
#  Row(ts=1513789074284),
#  Row(ts=1513789177284),
#  Row(ts=1513789209284),
#  Row(ts=1513790681284),
#  Row(ts=1513795535284),
#  Row(ts=1513800882284),
#  Row(ts=1513801434284),
#  Row(ts=1513805286284),
#  Row(ts=1513806348284),
#  Row(ts=1513807787284),
#  Row(ts=1513809557284),
#  Row(ts=1513812857284),
#  Row(ts=1513813594284),
#  Row(ts=1513824943284),
#  Row(ts=1513826563284),
#  Row(ts=1513826578284),
#  Row(ts=1513827537284),
#  Row(ts=1513830134284),
#  Row(ts=1513838249284),
#  Row(ts=1513838647284),
#  Row(ts=1513845056284),
#  Row(ts=1513721716284),
#  Row(ts=1513732533284),
#  Row(ts=1513736437284),
#  Row(ts=1513736695284),
#  Row(ts=1513738749284),
#  Row(ts=1513744224284),
#  Row(ts=1513753997284),
#  Row(ts=1513758510284),
#  Row(ts=1513762196284),
#  Row(ts=1513766096284),
#  Row(ts=1513767203284),
#  Row(ts=1513773061284),
#  Row(ts=1513775694284),
#  Row(ts=1513776685284),
#  Row(ts=1513782455284),
#  Row(ts=1513783320284),
#  Row(ts=1513784021284),
#  Row(ts=1513785245284),
#  Row(ts=1513785734284),
#  Row(ts=1513785943284),
#  Row(ts=1513787545284),
#  Row(ts=1513788274284),
#  Row(ts=1513788563284),
#  Row(ts=1513791994284),
#  Row(ts=1513792696284),
#  Row(ts=1513794918284),
#  Row(ts=1513795660284),
#  Row(ts=1513797974284),
#  Row(ts=1513803090284),
#  Row(ts=1513804366284),
#  Row(ts=1513811877284),
#  Row(ts=1513817975284),
#  Row(ts=1513823282284),
#  Row(ts=1513823471284),
#  Row(ts=1513823870284),
#  Row(ts=1513832351284),
#  Row(ts=1513833172284),
#  Row(ts=1513833829284),
#  Row(ts=1513837905284),
#  Row(ts=1513845866284),
#  Row(ts=1513847424284),
#  Row(ts=1513721321284),
#  Row(ts=1513730153284),
#  Row(ts=1513731278284),
#  Row(ts=1513733453284),
#  Row(ts=1513737989284),
#  Row(ts=1513739508284),
#  Row(ts=1513744733284),
#  Row(ts=1513746584284),
#  Row(ts=1513758551284),
#  Row(ts=1513763996284),
#  Row(ts=1513767793284),
#  Row(ts=1513775411284),
#  Row(ts=1513776475284),
#  Row(ts=1513777819284),
#  Row(ts=1513778453284),
#  Row(ts=1513779064284),
#  Row(ts=1513781754284),
#  Row(ts=1513781985284),
#  Row(ts=1513782833284),
#  Row(ts=1513783360284),
#  Row(ts=1513783889284),
#  Row(ts=1513784167284),
#  Row(ts=1513784208284),
#  Row(ts=1513784701284),
#  Row(ts=1513786301284),
#  Row(ts=1513787441284),
#  Row(ts=1513789812284),
#  Row(ts=1513790787284),
#  Row(ts=1513790878284),
#  Row(ts=1513791812284),
#  Row(ts=1513794185284),
#  Row(ts=1513794880284),
#  Row(ts=1513794957284),
#  Row(ts=1513798315284),
#  Row(ts=1513799322284),
#  Row(ts=1513799805284),
#  Row(ts=1513801054284),
#  Row(ts=1513801117284),
#  Row(ts=1513801925284),
#  Row(ts=1513802969284),
#  Row(ts=1513804555284),
#  Row(ts=1513805574284),
#  Row(ts=1513809200284),
#  Row(ts=1513809603284),
#  Row(ts=1513811259284),
#  Row(ts=1513817940284),
#  Row(ts=1513819434284),
#  Row(ts=1513821699284),
#  Row(ts=1513824498284),
#  Row(ts=1513824730284),
#  Row(ts=1513835308284),
#  Row(ts=1513837433284),
#  Row(ts=1513839199284),
#  Row(ts=1513839673284),
#  Row(ts=1513844586284),
#  Row(ts=1513847165284),
#  Row(ts=1513729526284),
#  Row(ts=1513749124284),
#  Row(ts=1513749501284),
#  Row(ts=1513750345284),
#  Row(ts=1513753899284),
#  Row(ts=1513755961284),
#  Row(ts=1513762132284),
#  Row(ts=1513768362284),
#  Row(ts=1513770148284),
#  Row(ts=1513776896284),
#  Row(ts=1513779874284),
#  Row(ts=1513780420284),
#  Row(ts=1513782250284),
#  Row(ts=1513783036284),
#  Row(ts=1513783097284),
#  Row(ts=1513788400284),
#  Row(ts=1513789411284),
#  Row(ts=1513790944284),
#  Row(ts=1513790959284),
#  Row(ts=1513791512284),
#  Row(ts=1513792146284),
#  Row(ts=1513794292284),
#  Row(ts=1513797097284),
#  Row(ts=1513799468284),
#  Row(ts=1513804066284),
#  Row(ts=1513812466284),
#  Row(ts=1513812870284),
#  Row(ts=1513813071284),
#  Row(ts=1513814691284),
#  Row(ts=1513822029284),
#  Row(ts=1513830726284),
#  Row(ts=1513830968284),
#  Row(ts=1513833479284),
#  Row(ts=1513839667284),
#  Row(ts=1513843031284),
#  Row(ts=1513844747284),
#  Row(ts=1513844858284),
#  Row(ts=1513722257284),
#  Row(ts=1513724939284),
#  Row(ts=1513725543284),
#  Row(ts=1513726548284),
#  Row(ts=1513727243284),
#  Row(ts=1513730267284),
#  Row(ts=1513731135284),
#  Row(ts=1513738995284),
#  Row(ts=1513744932284),
#  Row(ts=1513746283284),
#  Row(ts=1513752928284),
#  Row(ts=1513757604284),
#  Row(ts=1513760789284),
#  Row(ts=1513761668284),
#  Row(ts=1513762815284),
#  Row(ts=1513774994284),
#  Row(ts=1513777604284),
#  Row(ts=1513781023284),
#  Row(ts=1513781419284),
#  Row(ts=1513782670284),
#  Row(ts=1513783207284),
#  Row(ts=1513784433284),
#  Row(ts=1513784679284),
#  Row(ts=1513785806284),
#  Row(ts=1513790321284),
#  Row(ts=1513792161284),
#  Row(ts=1513793638284),
#  Row(ts=1513795319284),
#  Row(ts=1513796548284),
#  Row(ts=1513807911284),
#  Row(ts=1513808700284),
#  Row(ts=1513810581284),
#  Row(ts=1513812907284),
#  Row(ts=1513813965284),
#  Row(ts=1513819340284),
#  Row(ts=1513819871284),
#  Row(ts=1513823365284),
#  Row(ts=1513824952284),
#  Row(ts=1513825608284),
#  Row(ts=1513830676284),
#  Row(ts=1513835462284),
#  Row(ts=1513836081284),
#  Row(ts=1513837660284),
#  Row(ts=1513840414284),
#  Row(ts=1513841521284),
#  Row(ts=1513722009284),
#  Row(ts=1513725870284),
#  Row(ts=1513729857284),
#  Row(ts=1513733917284),
#  Row(ts=1513735959284),
#  Row(ts=1513736040284),
#  Row(ts=1513736352284),
#  Row(ts=1513737623284),
#  Row(ts=1513737804284),
#  Row(ts=1513741992284),
#  Row(ts=1513744352284),
#  Row(ts=1513747288284),
#  Row(ts=1513752332284),
#  Row(ts=1513753016284),
#  Row(ts=1513756679284),
#  Row(ts=1513757536284),
#  Row(ts=1513765029284),
#  Row(ts=1513765333284),
#  Row(ts=1513774380284),
#  Row(ts=1513775742284),
#  Row(ts=1513775769284),
#  Row(ts=1513777088284),
#  Row(ts=1513777818284),
#  Row(ts=1513781169284),
#  Row(ts=1513784118284),
#  Row(ts=1513785855284),
#  Row(ts=1513790375284),
#  Row(ts=1513790700284),
#  Row(ts=1513792091284),
#  Row(ts=1513792517284),
#  Row(ts=1513792586284),
#  Row(ts=1513799436284),
#  Row(ts=1513799970284),
#  Row(ts=1513803081284),
#  Row(ts=1513803980284),
#  Row(ts=1513805239284),
#  Row(ts=1513808546284),
#  Row(ts=1513816043284),
#  Row(ts=1513818657284),
#  Row(ts=1513824472284),
#  Row(ts=1513828295284),
#  Row(ts=1513828848284),
#  Row(ts=1513832070284),
#  Row(ts=1513833341284),
#  Row(ts=1513841953284),
#  Row(ts=1513843755284),
#  Row(ts=1513722721284),
#  Row(ts=1513723192284),
#  Row(ts=1513726130284),
#  Row(ts=1513729293284),
#  Row(ts=1513734035284),
#  Row(ts=1513736082284),
#  Row(ts=1513740927284),
#  Row(ts=1513744617284),
#  Row(ts=1513746313284),
#  Row(ts=1513756564284),
#  Row(ts=1513757200284),
#  Row(ts=1513757733284),
#  Row(ts=1513757790284),
#  Row(ts=1513763284284),
#  Row(ts=1513768271284),
#  Row(ts=1513770263284),
#  Row(ts=1513771785284),
#  Row(ts=1513772615284),
#  Row(ts=1513774090284),
#  Row(ts=1513776494284),
#  Row(ts=1513782629284),
#  Row(ts=1513784495284),
#  Row(ts=1513790320284),
#  Row(ts=1513790566284),
#  Row(ts=1513791035284),
#  Row(ts=1513791702284),
#  Row(ts=1513792677284),
#  Row(ts=1513792953284),
#  Row(ts=1513793752284),
#  Row(ts=1513796590284),
#  Row(ts=1513796822284),
#  Row(ts=1513797950284),
#  Row(ts=1513798181284),
#  Row(ts=1513799510284),
#  Row(ts=1513799767284),
#  Row(ts=1513804092284),
#  Row(ts=1513805355284),
#  Row(ts=1513812986284),
#  Row(ts=1513813193284),
#  Row(ts=1513826948284),
#  Row(ts=1513829203284),
#  Row(ts=1513835304284),
#  Row(ts=1513836595284),
#  Row(ts=1513836811284),
#  Row(ts=1513843250284),
#  Row(ts=1513845905284),
#  Row(ts=1513723183284),
#  Row(ts=1513724364284),
#  Row(ts=1513724519284),
#  Row(ts=1513727858284),
#  Row(ts=1513729313284),
#  Row(ts=1513730261284),
#  Row(ts=1513730481284),
#  Row(ts=1513737748284),
#  Row(ts=1513742024284),
#  Row(ts=1513745054284),
#  Row(ts=1513755231284),
#  Row(ts=1513757628284),
#  Row(ts=1513760449284),
#  Row(ts=1513763289284),
#  Row(ts=1513764059284),
#  Row(ts=1513767521284),
#  Row(ts=1513768496284),
#  Row(ts=1513770350284),
#  Row(ts=1513776480284),
#  Row(ts=1513776651284),
#  Row(ts=1513777822284),
#  Row(ts=1513778304284),
#  Row(ts=1513778801284),
#  Row(ts=1513779383284),
#  Row(ts=1513782133284),
#  Row(ts=1513783607284),
#  Row(ts=1513784024284),
#  Row(ts=1513784266284),
#  Row(ts=1513784607284),
#  Row(ts=1513786465284),
#  Row(ts=1513789244284),
#  Row(ts=1513792159284),
#  Row(ts=1513797127284),
#  Row(ts=1513797128284),
#  Row(ts=1513798613284),
#  Row(ts=1513799009284),
#  Row(ts=1513799186284),
#  Row(ts=1513800783284),
#  Row(ts=1513810488284),
#  Row(ts=1513812352284),
#  Row(ts=1513813773284),
#  Row(ts=1513814648284),
#  Row(ts=1513814915284),
#  Row(ts=1513816600284),
#  Row(ts=1513817049284),
#  Row(ts=1513822963284),
#  Row(ts=1513825113284),
#  Row(ts=1513826008284),
#  Row(ts=1513826494284),
#  Row(ts=1513831085284),
#  Row(ts=1513839984284),
#  Row(ts=1513842410284),
#  Row(ts=1513843241284),
#  Row(ts=1513843760284),
#  Row(ts=1513846028284),
#  Row(ts=1513721127284),
#  Row(ts=1513726049284),
#  Row(ts=1513727476284),
#  Row(ts=1513729994284),
#  Row(ts=1513738231284),
#  Row(ts=1513740270284),
#  Row(ts=1513744158284),
#  Row(ts=1513746328284),
#  Row(ts=1513752791284),
#  Row(ts=1513759746284),
#  Row(ts=1513761495284),
#  Row(ts=1513762729284),
#  Row(ts=1513762976284),
#  Row(ts=1513768044284),
#  Row(ts=1513771051284),
#  Row(ts=1513775598284),
#  Row(ts=1513779022284),
#  Row(ts=1513779828284),
#  Row(ts=1513779929284),
#  Row(ts=1513781040284),
#  Row(ts=1513781217284),
#  Row(ts=1513781920284),
#  Row(ts=1513782544284),
#  Row(ts=1513785670284),
#  Row(ts=1513789134284),
#  Row(ts=1513789154284),
#  Row(ts=1513790530284),
#  Row(ts=1513792322284),
#  Row(ts=1513795267284),
#  Row(ts=1513798882284),
#  Row(ts=1513801937284),
#  Row(ts=1513802952284),
#  Row(ts=1513804022284),
#  Row(ts=1513805402284),
#  Row(ts=1513807020284),
#  Row(ts=1513807453284),
#  Row(ts=1513809086284),
#  Row(ts=1513811037284),
#  Row(ts=1513814115284),
#  Row(ts=1513816670284),
#  Row(ts=1513819925284),
#  Row(ts=1513822379284),
#  Row(ts=1513828603284),
#  Row(ts=1513830380284),
#  Row(ts=1513833144284),
#  Row(ts=1513836872284),
#  Row(ts=1513841087284),
#  Row(ts=1513723960284),
#  Row(ts=1513724799284),
#  Row(ts=1513730001284),
#  Row(ts=1513732236284),
#  Row(ts=1513734406284),
#  Row(ts=1513738805284),
#  Row(ts=1513742908284),
#  Row(ts=1513754691284),
#  Row(ts=1513755642284),
#  Row(ts=1513755671284),
#  Row(ts=1513758312284),
#  Row(ts=1513760902284),
#  Row(ts=1513771133284),
#  Row(ts=1513775858284),
#  Row(ts=1513775927284),
#  Row(ts=1513776134284),
#  Row(ts=1513778620284),
#  Row(ts=1513779818284),
#  Row(ts=1513779933284),
#  Row(ts=1513780083284),
#  Row(ts=1513780104284),
#  Row(ts=1513780216284),
#  Row(ts=1513780421284),
#  Row(ts=1513782398284),
#  Row(ts=1513784421284),
#  Row(ts=1513784490284),
#  Row(ts=1513785507284),
#  Row(ts=1513787062284),
#  Row(ts=1513789202284),
#  Row(ts=1513789994284),
#  Row(ts=1513790017284),
#  Row(ts=1513790891284),
#  Row(ts=1513791966284),
#  Row(ts=1513793025284),
#  Row(ts=1513793550284),
#  Row(ts=1513797797284),
#  Row(ts=1513798138284),
#  Row(ts=1513802003284),
#  Row(ts=1513802296284),
#  Row(ts=1513803454284),
#  Row(ts=1513811939284),
#  Row(ts=1513817216284),
#  Row(ts=1513817271284),
#  Row(ts=1513818341284),
#  Row(ts=1513820851284),
#  Row(ts=1513821772284),
#  Row(ts=1513829875284),
#  Row(ts=1513831883284),
#  Row(ts=1513835779284),
#  Row(ts=1513835927284),
#  Row(ts=1513841660284),
#  Row(ts=1513844323284),
#  Row(ts=1513725530284),
#  Row(ts=1513726013284),
#  Row(ts=1513729402284),
#  Row(ts=1513730081284),
#  Row(ts=1513732029284),
#  Row(ts=1513736929284),
#  Row(ts=1513738594284),
#  Row(ts=1513743961284),
#  Row(ts=1513750624284),
#  Row(ts=1513752823284),
#  Row(ts=1513765825284),
#  Row(ts=1513772126284),
#  Row(ts=1513775806284),
#  Row(ts=1513781476284),
#  Row(ts=1513781686284),
#  Row(ts=1513783806284),
#  Row(ts=1513785062284),
#  Row(ts=1513785064284),
#  Row(ts=1513785114284),
#  Row(ts=1513788175284),
#  Row(ts=1513794418284),
#  Row(ts=1513794639284),
#  Row(ts=1513795889284),
#  Row(ts=1513803709284),
#  Row(ts=1513804420284),
#  Row(ts=1513804786284),
#  Row(ts=1513807327284),
#  Row(ts=1513811770284),
#  Row(ts=1513815046284),
#  Row(ts=1513817608284),
#  Row(ts=1513817762284),
#  Row(ts=1513820259284),
#  Row(ts=1513821061284),
#  Row(ts=1513827058284),
#  Row(ts=1513830668284),
#  Row(ts=1513837244284),
#  Row(ts=1513838225284),
#  Row(ts=1513838520284),
#  Row(ts=1513841169284),
#  Row(ts=1513841658284),
#  Row(ts=1513842400284),
#  Row(ts=1513842721284),
#  Row(ts=1513842955284),
#  Row(ts=1513844251284),
#  Row(ts=1513847179284),
#  Row(ts=1513847435284),
#  Row(ts=1513730159284),
#  Row(ts=1513730258284),
#  Row(ts=1513732342284),
#  Row(ts=1513737035284),
#  Row(ts=1513737728284),
#  Row(ts=1513745517284),
#  Row(ts=1513762634284),
#  Row(ts=1513767851284),
#  Row(ts=1513767946284),
#  Row(ts=1513768831284),
#  Row(ts=1513775128284),
#  Row(ts=1513775882284),
#  Row(ts=1513775913284),
#  Row(ts=1513776179284),
#  Row(ts=1513777188284),
#  Row(ts=1513778650284),
#  Row(ts=1513778807284),
#  Row(ts=1513780635284),
#  Row(ts=1513781273284),
#  Row(ts=1513783185284),
#  Row(ts=1513783264284),
#  Row(ts=1513783306284),
#  Row(ts=1513783345284),
#  Row(ts=1513786767284),
#  Row(ts=1513787054284),
#  Row(ts=1513787082284),
#  Row(ts=1513787946284),
#  Row(ts=1513788285284),
#  Row(ts=1513788423284),
#  Row(ts=1513789894284),
#  Row(ts=1513789902284),
#  Row(ts=1513791701284),
#  Row(ts=1513793502284),
#  Row(ts=1513797649284),
#  Row(ts=1513798215284),
#  Row(ts=1513803932284),
#  Row(ts=1513805375284),
#  Row(ts=1513807533284),
#  Row(ts=1513822003284),
#  Row(ts=1513822576284),
#  Row(ts=1513827019284),
#  Row(ts=1513830327284),
#  Row(ts=1513836625284),
#  Row(ts=1513840466284),
#  Row(ts=1513843247284),
#  Row(ts=1513843488284),
#  Row(ts=1513724719284),
#  Row(ts=1513726132284),
#  Row(ts=1513726946284),
#  Row(ts=1513727327284),
#  Row(ts=1513727589284),
#  Row(ts=1513730197284),
#  Row(ts=1513733794284),
#  Row(ts=1513734990284),
#  Row(ts=1513742096284),
#  Row(ts=1513744369284),
#  Row(ts=1513753457284),
#  Row(ts=1513759043284),
#  Row(ts=1513759831284),
#  Row(ts=1513770608284),
#  Row(ts=1513770900284),
#  Row(ts=1513771406284),
#  Row(ts=1513774714284),
#  Row(ts=1513777690284),
#  Row(ts=1513779449284),
#  Row(ts=1513780524284),
#  Row(ts=1513781451284),
#  Row(ts=1513784824284),
#  Row(ts=1513786128284),
#  Row(ts=1513788273284),
#  Row(ts=1513788855284),
#  Row(ts=1513791245284),
#  Row(ts=1513792821284),
#  Row(ts=1513796792284),
#  Row(ts=1513803437284),
#  Row(ts=1513808318284),
#  Row(ts=1513814962284),
#  Row(ts=1513816850284),
#  Row(ts=1513817113284),
#  Row(ts=1513817690284),
#  Row(ts=1513818888284),
#  Row(ts=1513820683284),
#  Row(ts=1513825656284),
#  Row(ts=1513830233284),
#  Row(ts=1513830259284),
#  Row(ts=1513831104284),
#  Row(ts=1513838697284),
#  Row(ts=1513840741284),
#  Row(ts=1513843185284),
#  Row(ts=1513725305284),
#  Row(ts=1513726641284),
#  Row(ts=1513734265284),
#  Row(ts=1513735082284),
#  Row(ts=1513735962284),
#  Row(ts=1513739099284),
#  Row(ts=1513740012284),
#  Row(ts=1513742768284),
#  Row(ts=1513743746284),
#  Row(ts=1513748232284),
#  Row(ts=1513757581284),
#  Row(ts=1513760887284),
#  Row(ts=1513765779284),
#  Row(ts=1513771349284),
#  Row(ts=1513773556284),
#  Row(ts=1513777095284),
#  Row(ts=1513778406284),
#  Row(ts=1513783319284),
#  Row(ts=1513784013284),
#  Row(ts=1513785711284),
#  Row(ts=1513787245284),
#  Row(ts=1513788908284),
#  Row(ts=1513791444284),
#  Row(ts=1513792554284),
#  Row(ts=1513796501284),
#  Row(ts=1513797647284),
#  Row(ts=1513798522284),
#  Row(ts=1513807622284),
#  Row(ts=1513809547284),
#  Row(ts=1513810758284),
#  Row(ts=1513813364284),
#  Row(ts=1513815632284),
#  Row(ts=1513823370284),
#  Row(ts=1513823890284),
#  Row(ts=1513825199284),
#  Row(ts=1513831158284),
#  Row(ts=1513832478284),
#  Row(ts=1513839275284),
#  Row(ts=1513722508284),
#  Row(ts=1513722525284),
#  Row(ts=1513724833284),
#  Row(ts=1513725249284),
#  Row(ts=1513727885284),
#  Row(ts=1513728946284),
#  Row(ts=1513742726284),
#  Row(ts=1513755008284),
#  Row(ts=1513756681284),
#  Row(ts=1513758093284),
#  Row(ts=1513770564284),
#  Row(ts=1513771356284),
#  Row(ts=1513773226284),
#  Row(ts=1513775327284),
#  Row(ts=1513776083284),
#  Row(ts=1513776854284),
#  Row(ts=1513777206284),
#  Row(ts=1513777334284),
#  Row(ts=1513777962284),
#  Row(ts=1513779027284),
#  Row(ts=1513780472284),
#  Row(ts=1513782639284),
#  Row(ts=1513783904284),
#  Row(ts=1513784415284),
#  Row(ts=1513784848284),
#  Row(ts=1513785708284),
#  Row(ts=1513785776284),
#  Row(ts=1513788858284),
#  Row(ts=1513790010284),
#  Row(ts=1513790019284),
#  Row(ts=1513790580284),
#  Row(ts=1513791529284),
#  Row(ts=1513794881284),
#  Row(ts=1513795855284),
#  Row(ts=1513799253284),
#  Row(ts=1513800327284),
#  Row(ts=1513803754284),
#  Row(ts=1513804645284),
#  Row(ts=1513805615284),
#  Row(ts=1513813804284),
#  Row(ts=1513816923284),
#  Row(ts=1513820477284),
#  Row(ts=1513820672284),
#  Row(ts=1513821781284),
#  Row(ts=1513826387284),
#  Row(ts=1513829519284),
#  Row(ts=1513829619284),
#  Row(ts=1513831433284),
#  Row(ts=1513843060284),
#  Row(ts=1513844045284),
#  Row(ts=1513844589284),
#  Row(ts=1513846059284),
#  Row(ts=1513722485284),
#  Row(ts=1513723703284),
#  Row(ts=1513727803284),
#  Row(ts=1513731410284),
#  Row(ts=1513749835284),
#  Row(ts=1513752942284),
#  Row(ts=1513754457284),
#  Row(ts=1513755992284),
#  Row(ts=1513761031284),
#  Row(ts=1513764513284),
#  Row(ts=1513765700284),
#  Row(ts=1513765773284),
#  Row(ts=1513766105284),
#  Row(ts=1513766277284),
#  Row(ts=1513766586284),
#  Row(ts=1513769711284),
#  Row(ts=1513771040284),
#  Row(ts=1513773201284),
#  Row(ts=1513773289284),
#  Row(ts=1513774702284),
#  Row(ts=1513776277284),
#  Row(ts=1513777140284),
#  Row(ts=1513778606284),
#  Row(ts=1513781195284),
#  Row(ts=1513781805284),
#  Row(ts=1513781980284),
#  Row(ts=1513783054284),
#  Row(ts=1513784449284),
#  Row(ts=1513785393284),
#  Row(ts=1513787849284),
#  Row(ts=1513790385284),
#  Row(ts=1513795548284),
#  Row(ts=1513796124284),
#  Row(ts=1513800125284),
#  Row(ts=1513802287284),
#  Row(ts=1513802965284),
#  Row(ts=1513803835284),
#  Row(ts=1513804437284),
#  Row(ts=1513805183284),
#  Row(ts=1513805335284),
#  Row(ts=1513810819284),
#  Row(ts=1513811073284),
#  Row(ts=1513815931284),
#  Row(ts=1513818322284),
#  Row(ts=1513818636284),
#  Row(ts=1513829776284),
#  Row(ts=1513831982284),
#  Row(ts=1513844022284),
#  Row(ts=1513844899284),
#  Row(ts=1513847023284),
#  Row(ts=1513721933284),
#  Row(ts=1513723482284),
#  Row(ts=1513726303284),
#  Row(ts=1513732010284),
#  Row(ts=1513732198284),
#  Row(ts=1513736243284),
#  Row(ts=1513741362284),
#  Row(ts=1513743939284),
#  Row(ts=1513751935284),
#  Row(ts=1513757329284),
#  Row(ts=1513763623284),
#  Row(ts=1513766428284),
#  Row(ts=1513769067284),
#  Row(ts=1513772960284),
#  Row(ts=1513778770284),
#  Row(ts=1513779682284),
#  Row(ts=1513780037284),
#  Row(ts=1513780913284),
#  Row(ts=1513782708284),
#  Row(ts=1513784918284),
#  Row(ts=1513785219284),
#  Row(ts=1513786426284),
#  Row(ts=1513787803284),
#  Row(ts=1513788390284),
#  Row(ts=1513789474284),
#  Row(ts=1513789780284),
#  Row(ts=1513790762284),
#  Row(ts=1513791042284),
#  Row(ts=1513793452284),
#  Row(ts=1513794675284),
#  Row(ts=1513795661284),
#  Row(ts=1513797301284),
#  Row(ts=1513797684284),
#  Row(ts=1513800680284),
#  Row(ts=1513800970284),
#  Row(ts=1513803784284),
#  Row(ts=1513804730284),
#  Row(ts=1513809901284),
#  Row(ts=1513815040284),
#  Row(ts=1513816231284),
#  Row(ts=1513825193284),
#  Row(ts=1513837073284),
#  Row(ts=1513837456284),
#  Row(ts=1513838077284),
#  Row(ts=1513840270284),
#  Row(ts=1513840493284),
#  Row(ts=1513845132284),
#  Row(ts=1513846958284),
#  Row(ts=1513720878284),
#  Row(ts=1513724390284),
#  Row(ts=1513725478284),
#  Row(ts=1513729078284),
#  Row(ts=1513734675284),
#  Row(ts=1513736045284),
#  Row(ts=1513740870284),
#  Row(ts=1513741311284),
#  Row(ts=1513741856284),
#  Row(ts=1513742143284),
#  Row(ts=1513742309284),
#  Row(ts=1513750027284),
#  Row(ts=1513751436284),
#  Row(ts=1513752057284),
#  Row(ts=1513757114284),
#  Row(ts=1513765818284),
#  Row(ts=1513773243284),
#  Row(ts=1513773888284),
#  Row(ts=1513774204284),
#  Row(ts=1513775223284),
#  Row(ts=1513777148284),
#  Row(ts=1513780409284),
#  Row(ts=1513784558284),
#  Row(ts=1513784564284),
#  Row(ts=1513784802284),
#  Row(ts=1513785202284),
#  Row(ts=1513786051284),
#  Row(ts=1513786370284),
#  Row(ts=1513787095284),
#  Row(ts=1513787248284),
#  Row(ts=1513787494284),
#  Row(ts=1513789706284),
#  Row(ts=1513789831284),
#  Row(ts=1513791370284),
#  Row(ts=1513792416284),
#  Row(ts=1513792808284),
#  Row(ts=1513792836284),
#  Row(ts=1513794511284),
#  Row(ts=1513798380284),
#  Row(ts=1513804157284),
#  Row(ts=1513805419284),
#  Row(ts=1513811435284),
#  Row(ts=1513812796284),
#  Row(ts=1513813794284),
#  Row(ts=1513814861284),
#  Row(ts=1513827346284),
#  Row(ts=1513833077284),
#  Row(ts=1513841171284),
#  Row(ts=1513847870284),
#  Row(ts=1513848316284),
#  Row(ts=1513727159284),
#  Row(ts=1513733832284),
#  Row(ts=1513735054284),
#  Row(ts=1513736774284),
#  Row(ts=1513737481284),
#  Row(ts=1513737662284),
#  Row(ts=1513741294284),
#  Row(ts=1513742425284),
#  Row(ts=1513746989284),
#  Row(ts=1513750266284),
#  Row(ts=1513754031284),
#  Row(ts=1513756709284),
#  Row(ts=1513759518284),
#  Row(ts=1513764578284),
#  Row(ts=1513768632284),
#  Row(ts=1513769420284),
#  Row(ts=1513772653284),
#  Row(ts=1513774508284),
#  Row(ts=1513775981284),
#  Row(ts=1513777209284),
#  Row(ts=1513778669284),
#  Row(ts=1513779015284),
#  Row(ts=1513779265284),
#  Row(ts=1513781775284),
#  Row(ts=1513783379284),
#  Row(ts=1513783814284),
#  Row(ts=1513784353284),
#  Row(ts=1513785130284),
#  Row(ts=1513785281284),
#  Row(ts=1513785785284),
#  Row(ts=1513786989284),
#  Row(ts=1513788511284),
#  Row(ts=1513788711284),
#  Row(ts=1513791400284),
#  Row(ts=1513792571284),
#  Row(ts=1513795234284),
#  Row(ts=1513797622284),
#  Row(ts=1513801044284),
#  Row(ts=1513804829284),
#  ...]

# %%
# TODO: filter out 0 sum and max sum to get more exact answer

function = udf(lambda ishome : int(ishome == 'Home'), IntegerType())

user_window = Window \
    .partitionBy('userID') \
    .orderBy(desc('ts')) \
    .rangeBetween(Window.unboundedPreceding, 0)

cusum = df.filter((df.page == 'NextSong') | (df.page == 'Home')) \
    .select('userID', 'page', 'ts') \
    .withColumn('homevisit', function(col('page'))) \
    .withColumn('period', Fsum('homevisit').over(user_window))

cusum.filter((cusum.page == 'NextSong')) \
    .groupBy('userID', 'period') \
    .agg({'period':'count'}) \
    .agg({'count(period)':'avg'}).show()
# Out:
# +------------------+
# |avg(count(period))|
# +------------------+
# | 6.898347107438017|
# +------------------+
